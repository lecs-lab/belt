# %% [markdown]
# # **Introduction**
#
# Welcome to Building Endangered Language Technology! This course will teach you everything you need to build apps and tools for low-resource languages.

# %% [markdown]
# ## **Course Overview**
# <div>
# <img src="https://raw.githubusercontent.com/lecs-lab/belt/main/notebooks/assets/course.png" width="500" style=" display: block; margin-left: auto; margin-right: auto;"/>
# </div>
#
# The course consists of two components:
# - **Skills** are short lessons that teach a single skill you'll need to build language technology
# - **Projects** combine skills to build actual apps such as a spellchecker
#
# If you already have a programming background, some of the skills may be a review–feel free to pick and choose lesson that you want to learn about.

# %% [markdown]
# ## **The Google Colab Environment**
# All the lessons in this course open in [Google Colab](https://colab.research.google.com), the environment we are in now. Colab is a free service from Google that runs Python notebooks in the cloud, so you don't need to install anything on your computer. All you need is a web browser and a Google account.
#
# A notebook combines **text cells** (like this one) and **code cells**.
#
# ### Code cells
# The following is an example of a code cell:

# %%
print("Hello world")

# %% [markdown]
# <!-- TODO: this screenshot is from JupyterLab and needs to be replaced with a Colab one -->
# To run a code cell, click the **play button** on the left side of the cell, or click the cell and press **Shift + Enter**.
#
# <div>
# <img src="https://raw.githubusercontent.com/lecs-lab/belt/main/notebooks/assets/run-cells.png" width="500" style=" display: block; margin-left: auto; margin-right: auto;"/>
# </div>
#
# The first time you run a cell, Colab may show a warning that this notebook was not authored by Google. That's expected, since the lessons are hosted on our GitHub page. Click **Run anyway** to continue.
#
# When you run a code cell, it may print output right below it. The first run can take a few extra seconds while Colab connects you to a machine in the cloud.
#
# ### Too many sessions
# Colab only lets you run a few notebooks at the same time. If you open more than three, you may see a "Too many sessions" error when you try to run a cell. If that happens, select **Runtime** -> **Manage sessions** and terminate the notebooks you're not using, then run the cell again.

# %% [markdown]
# ### Sidebar
# <!-- TODO: these screenshots are from JupyterLab and need to be replaced with Colab ones -->
# On the left side of the screen is a sidebar with a few useful icons.
#
# <div>
# <img src="https://raw.githubusercontent.com/lecs-lab/belt/main/notebooks/assets/toc.png" width="300" style=" display: block; margin-left: auto; margin-right: auto;"/>
# </div>
#
# The **Table of contents** (the list icon) shows an overview of the current lesson so you can quickly jump to a section.
#
# <img src="https://raw.githubusercontent.com/lecs-lab/belt/main/notebooks/assets/files.png" width="300" style=" display: block; margin-left: auto; margin-right: auto;"/>
#
# The **Files** panel (the folder icon) lets you view, open, and upload files. If you want to upload your own corpora, you can do that by pressing the upload button at the top of the Files panel.
#
# **Important:** files you upload to Colab are temporary. When you close the notebook or the session times out, uploaded files are deleted, and you will need to upload them again next time. Later lessons explain how to load corpora automatically so this isn't a problem.
#
# ### Saving your work
# The lessons open in read-only mode. To save your progress and edits, select **File** -> **Save a copy in Drive**. This puts a personal copy of the notebook in your own Google Drive, and any changes you make there are saved automatically.

# %% [markdown]
# ## **Lesson Structure**
# Lessons will consist of a mixture of pre-written code, exercises, and challenges. You should carefully study all pre-written code to make sure you understand what it does. **Exercises** are short coding tasks within a lesson that check your comprehension. **Challenges** are optional tasks after the main lesson, that will be more challenging and really test your knowledge. The best way to learn to code is by coding, so we highly recommend you do as many of the exercises and challenges as you have time for.

# %% [markdown]
# ## **Your first exercise**
#
# For your first exercise, modify the following code cell so that instead of printing "Hello, Michael", it prints "Hello \<your name>". After you've modified the cell, make sure you can run it and it prints the output as you expect.

# %%
print("Hello, Michael")

# %% [markdown]
# [Next Lesson](https://colab.research.google.com/github/lecs-lab/belt/blob/main/notebooks/en/skills/2.%20Python.ipynb)
